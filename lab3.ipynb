# %%
pip install nltk

# %%
import nltk
nltk.download('all') #
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %%
# Path to the file in Google Drive
file_path = '/content/Sleep disorder.txt'
# Read the file
with open(file_path,'r') as f:
     print(f.read())
# Out:
# Some people have conditions that prevent them from getting enough quality sleep, no matter how hard they try. These problems are called sleep disorders. The most common sleep disorder is insomnia. “Insomnia is when you have repeated difficulty getting to sleep and/or staying asleep,” says Brown. This happens despite having the time to sleep and a proper sleep environment. It can make you feel tired or unrested during the day. Insomnia can be short-term, where people struggle to sleep for a few weeks or months. “Quite a few more people have been experiencing this during the pandemic,” Brown says. Long-term insomnia lasts for three months or longer. Sleep apnea is another common sleep disorder. In sleep apnea, the upper airway becomes blocked during sleep. This reduces or stops airflow, which wakes people up during the night. The condition can be dangerous. If untreated, it may lead to other health problems. If you regularly have problems sleeping, talk with your health care provider. 
# ...

# %% [markdown]
# Sentence Tokenization

# %%
from nltk.tokenize import sent_tokenize

text = """Some people have conditions that prevent them from getting enough quality sleep, no matter how hard they try. These problems are called sleep disorders. The most common sleep disorder is insomnia. “Insomnia is when you have repeated difficulty getting to sleep and/or staying asleep,” says Brown. This happens despite having the time to sleep and a proper sleep environment. It can make you feel tired or unrested during the day. Insomnia can be short-term, where people struggle to sleep for a few weeks or months. “Quite a few more people have been experiencing this during the pandemic,” Brown says. Long-term insomnia lasts for three months or longer. Sleep apnea is another common sleep disorder. In sleep apnea, the upper airway becomes blocked during sleep. This reduces or stops airflow, which wakes people up during the night. The condition can be dangerous. If untreated, it may lead to other health problems. If you regularly have problems sleeping, talk with your health care provider. They may have you keep a sleep diary to track your sleep for several weeks. They can also run tests, including sleep studies. These look for sleep disorders."""

sentences = sent_tokenize(text)
for sentence in sentences:
    print(sentence)
# Out:
# Some people have conditions that prevent them from getting enough quality sleep, no matter how hard they try.
# These problems are called sleep disorders.
# The most common sleep disorder is insomnia.
# “Insomnia is when you have repeated difficulty getting to sleep and/or staying asleep,” says Brown.
# This happens despite having the time to sleep and a proper sleep environment.
# It can make you feel tired or unrested during the day.
# Insomnia can be short-term, where people struggle to sleep for a few weeks or months.
# “Quite a few more people have been experiencing this during the pandemic,” Brown says.
# Long-term insomnia lasts for three months or longer.
# Sleep apnea is another common sleep disorder.
# In sleep apnea, the upper airway becomes blocked during sleep.
# This reduces or stops airflow, which wakes people up during the night.
# The condition can be dangerous.
# If untreated, it may lead to other health problems.
# ...

# %% [markdown]
# Word Tokenisation

# %%
from nltk.tokenize import word_tokenize

words = word_tokenize(text)
for word in words:
    print(word)
# Out:
# Some
# people
# have
# conditions
# that
# prevent
# them
# from
# getting
# enough
# quality
# sleep
# ,
# no
# matter
# how
# hard
# they
# try
# .
# These
# problems
# are
# called
# sleep
# disorders
# .
# The
# most
# common
# sleep
# disorder
# is
# insomnia
# .
# “
# Insomnia
# is
# when
# you
# have
# repeated
# difficulty
# getting
# to
# sleep
# and/or
# staying
# asleep
# ,
# ”
# says
# Brown
# .
# This
# happens
# despite
# having
# the
# time
# to
# sleep
# and
# a
# proper
# sleep
# environment
# .
# It
# can
# make
# you
# feel
# tired
# or
# unrested
# during
# the
# day
# .
# Insomnia
# can
# be
# short-term
# ,
# where
# people
# struggle
# to
# sleep
# for
# a
# few
# weeks
# or
# months
# .
# “
# Quite
# a
# few
# more
# people
# have
# been
# experiencing
# this
# during
# the
# pandemic
# ,
# ”
# Brown
# says
# .
# Long-term
# insomnia
# lasts
# for
# three
# months
# or
# longer
# .
# Sleep
# apnea
# is
# another
# common
# sleep
# disorder
# .
# In
# sleep
# ...

# %% [markdown]
# Stop Words Removal

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Download necessary resources
nltk.download('punkt')
nltk.download('stopwords')

# Path to the file in Google Drive
file_path = '/content/Sleep disorder.txt'

# Read the file and store it in a variable
with open(file_path, 'r') as f:
    text = f.read()

# Tokenize the text into words
words = word_tokenize(text)

# Get the list of stop words in English
stop_words = set(stopwords.words('english'))

# Remove stop words from the tokenized words
filtered_words = [word for word in words if word.lower() not in stop_words]

# Print the filtered words
for word in filtered_words:
    print(word)
# Out:
# people
# conditions
# prevent
# getting
# enough
# quality
# sleep
# ,
# matter
# hard
# try
# .
# problems
# called
# sleep
# disorders
# .
# common
# sleep
# disorder
# insomnia
# .
# “
# Insomnia
# repeated
# difficulty
# getting
# sleep
# and/or
# staying
# asleep
# ,
# ”
# says
# Brown
# .
# happens
# despite
# time
# sleep
# proper
# sleep
# environment
# .
# make
# feel
# tired
# unrested
# day
# .
# Insomnia
# short-term
# ,
# people
# struggle
# sleep
# weeks
# months
# .
# “
# Quite
# people
# experiencing
# pandemic
# ,
# ”
# Brown
# says
# .
# Long-term
# insomnia
# lasts
# three
# months
# longer
# .
# Sleep
# apnea
# another
# common
# sleep
# disorder
# .
# sleep
# apnea
# ,
# upper
# airway
# becomes
# blocked
# sleep
# .
# reduces
# stops
# airflow
# ,
# wakes
# people
# night
# .
# condition
# dangerous
# .
# untreated
# ,
# may
# lead
# health
# problems
# .
# regularly
# problems
# sleeping
# ,
# talk
# health
# care
# provider
# .
# may
# keep
# sleep
# diary
# ...

# %% [markdown]
# Stemming using the PorterStemmer

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Download necessary resources
nltk.download('punkt')

# Path to the file in Google Drive
file_path = '/content/Sleep disorder.txt'

# Read the file and store it in a variable
with open(file_path, 'r') as f:
    text = f.read()

# Tokenize the text into words
words = word_tokenize(text)

# Initialize the PorterStemmer
stemmer = PorterStemmer()

# Apply stemming to each word
stemmed_words = [stemmer.stem(word) for word in words]

# Print the stemmed words
for word in stemmed_words:
    print(word)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# some
# peopl
# have
# condit
# that
# prevent
# them
# from
# get
# enough
# qualiti
# sleep
# ,
# no
# matter
# how
# hard
# they
# tri
# .
# these
# problem
# are
# call
# sleep
# disord
# .
# the
# most
# common
# sleep
# disord
# is
# insomnia
# .
# “
# insomnia
# is
# when
# you
# have
# repeat
# difficulti
# get
# to
# sleep
# and/or
# stay
# asleep
# ,
# ”
# say
# brown
# .
# thi
# happen
# despit
# have
# the
# time
# to
# sleep
# and
# a
# proper
# sleep
# environ
# .
# it
# can
# make
# you
# feel
# tire
# or
# unrest
# dure
# the
# day
# .
# insomnia
# can
# be
# short-term
# ,
# where
# peopl
# struggl
# to
# sleep
# for
# a
# few
# week
# or
# month
# .
# “
# quit
# a
# few
# more
# peopl
# have
# been
# experienc
# thi
# dure
# the
# pandem
# ,
# ”
# brown
# say
# .
# long-term
# insomnia
# last
# for
# three
# month
# or
# longer
# .
# sleep
# apnea
# is
# ...

# %% [markdown]
# Lemmatization using WordNetLemmatizer

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary resources
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# Path to the file in Google Drive
file_path = '/content/Sleep disorder.txt'

# Read the file and store it in a variable
with open(file_path, 'r') as f:
    text = f.read()

# Tokenize the text into words
words = word_tokenize(text)

# Initialize the WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# Lemmatize each word
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

# Print the lemmatized words
for word in lemmatized_words:
    print(word)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# Some
# people
# have
# condition
# that
# prevent
# them
# from
# getting
# enough
# quality
# sleep
# ,
# no
# matter
# how
# hard
# they
# try
# .
# These
# problem
# are
# called
# sleep
# disorder
# .
# The
# most
# common
# sleep
# disorder
# is
# insomnia
# .
# “
# Insomnia
# is
# when
# you
# have
# repeated
# difficulty
# getting
# to
# sleep
# and/or
# staying
# asleep
# ,
# ”
# say
# Brown
# .
# This
# happens
# despite
# having
# the
# time
# to
# sleep
# and
# a
# proper
# sleep
# environment
# .
# It
# can
# make
# you
# feel
# tired
# or
# unrested
# during
# the
# day
# .
# Insomnia
# can
# be
# short-term
# ,
# where
# people
# struggle
# to
# sleep
# for
# a
# few
# week
# or
# month
# .
# “
# Quite
# a
# few
# more
# people
# have
# been
# experiencing
# this
# during
# the
# pandemic
# ,
# ”
# Brown
# say
# .
# Long-term
# insomnia
# last
# for
# three
# month
# or
# longer
# .
# Sleep
# apnea
# is
# ...

# %% [markdown]
# POS Tagging

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download necessary resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Path to the file in Google Drive
file_path = '/content/Sleep disorder.txt'

# Read the file and store it in a variable
with open(file_path, 'r') as f:
    text = f.read()

# Tokenize the text into words
words = word_tokenize(text)

# Perform POS tagging
pos_tags = nltk.pos_tag(words)

# Print the POS tags
for word, tag in pos_tags:
    print(f'{word}: {tag}')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# Some: DT
# people: NNS
# have: VBP
# conditions: NNS
# that: WDT
# prevent: VBP
# them: PRP
# from: IN
# getting: VBG
# enough: JJ
# quality: NN
# sleep: NN
# ,: ,
# no: DT
# matter: NN
# how: WRB
# hard: RB
# they: PRP
# try: VBP
# .: .
# These: DT
# problems: NNS
# are: VBP
# called: VBN
# sleep: JJ
# disorders: NNS
# .: .
# The: DT
# most: RBS
# common: JJ
# sleep: JJ
# disorder: NN
# is: VBZ
# insomnia: JJ
# .: .
# “: JJ
# Insomnia: NNP
# is: VBZ
# when: WRB
# you: PRP
# have: VBP
# repeated: VBN
# difficulty: NN
# getting: VBG
# to: TO
# sleep: VB
# and/or: NN
# staying: VBG
# asleep: RB
# ,: ,
# ”: NNP
# says: VBZ
# Brown: NNP
# .: .
# This: DT
# happens: VBZ
# despite: IN
# having: VBG
# the: DT
# time: NN
# to: TO
# sleep: VB
# and: CC
# a: DT
# proper: JJ
# sleep: NN
# environment: NN
# .: .
# It: PRP
# can: MD
# make: VB
# you: PRP
# feel: VB
# tired: JJ
# or: CC
# unrested: JJ
# during: IN
# the: DT
# day: NN
# ...

# %% [markdown]
# Named Entity Recognition (NER)

# %%
# Named Entity Recognition
nltk.download('maxent_ne_chunker')
nltk.download('words')

ner_result = nltk.ne_chunk(pos_tags)

print("\nNamed Entity Recognition:")
for subtree in ner_result:
    if isinstance(subtree, nltk.Tree):  # Named entity is identified
        entity = " ".join([word for word, tag in subtree])
        label = subtree.label()
        print(f"Entity: {entity}, Label: {label}")
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Named Entity Recognition:
# Entity: Insomnia, Label: GPE
# Entity: Brown, Label: PERSON
# Entity: Brown, Label: PERSON

# %% [markdown]
# Synonyms and Antonyms Exploration

# %%
from nltk.corpus import wordnet as wn

# Example word
word = "happy"

# Synonyms
synonyms = set()
for syn in wn.synsets(word):
    for lemma in syn.lemmas():
        synonyms.add(lemma.name())

# Antonyms
antonyms = set()
for syn in wn.synsets(word):
    for lemma in syn.lemmas():
        if lemma.antonyms():
            antonyms.add(lemma.antonyms()[0].name())

print(f"\nSynonyms of '{word}': {synonyms}")
print(f"Antonyms of '{word}': {antonyms}")
# Out:
# Synonyms of 'happy': {'glad', 'well-chosen', 'felicitous', 'happy'}
# Antonyms of 'happy': {'unhappy'}

# %% [markdown]
# Frequency Distribution (Before and After Removing Stopwords)

# %%
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

# Create a frequency distribution of words
fdist = FreqDist(filtered_words)
print("\nFrequency Distribution (After Stop Word Removal):")
print(fdist.most_common(10))

# Optional: Plot the frequency distribution
fdist.plot(30, cumulative=False)
plt.show()

# Frequency Distribution Before Stop Words Removal
fdist_all = FreqDist(words)
print("\nFrequency Distribution (Before Stop Word Removal):")
print(fdist_all.most_common(10))

# Optional: Plot the frequency distribution
fdist_all.plot(30, cumulative=False)
plt.show()
# Out:
# Frequency Distribution (After Stop Word Removal):
# [('.', 18), ('sleep', 14), (',', 9), ('people', 4), ('problems', 3), ('getting', 2), ('disorders', 2), ('common', 2), ('disorder', 2), ('insomnia', 2)]
# Frequency Distribution (Before Stop Word Removal):
# [('.', 18), ('sleep', 14), (',', 9), ('have', 5), ('to', 5), ('the', 5), ('people', 4), ('you', 4), ('a', 4), ('can', 4)]
